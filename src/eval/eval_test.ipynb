# %%
from google.colab import drive

drive.mount('/content/gdrive', force_remount=True)

path='gdrive/MyDrive/evaluation InContextLearning2024'

import sys
sys.path.append('/content/'+path)
# Out:
# Mounted at /content/gdrive

# %%
# %cd 'evaluation InContextLearning2024'
# Out:
# [Errno 2] No such file or directory: 'evaluation InContextLearning2024'
# /content

# %%
! ls
# Out:
# environment.yaml  src

# %%
from eval.eval import eval_model
from models.linear import LeastSquaresModel
from function_classes.linear import LinearRegression

from torch import nn

from torch import normal

# %%
config_data={"pretrained":True, 'function_class':LinearRegression(), "accuracy_func": nn.MSELoss()}

print(eval_model(LeastSquaresModel(), config_data))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-7c7e2a48b3ce> in <cell line: 1>()
# ----> 1 config_data={"pretrained":True, 'function_class':LinearRegression(), "accuracy_func": nn.MSELoss()}
#       2
#       3 print(eval_model(LeastSquaresModel(), config_data))
#
# TypeError: FunctionClass.__init__() missing 1 required positional argument: 'x_distribution'
